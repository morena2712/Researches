# %% [markdown]
# <a href="https://colab.research.google.com/github/morena2712/DataMiningProject/blob/main/TEST_ChatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **L'intelligenza Artificiale nella psicologia. Discussione e validazione di un questionario creato con Chat-GPT.**
#
# Il presente lavoro parte da una domanda di ricerca legata alle potenzialità, alle
# eventuali opportunità e ai limiti dell’IA nella ricerca psicologica e, nello specifico,
# nella generazione tramite Intelligenza Artificiale di strumenti di misurazione
# attendibili e validi se confrontati con strumenti elaborati da umani.\
# Con il seguente elaborato, si cercherà di dimostrare come l’IA può essere un
# importante alleato. In particolare, è stato utilizzato uno strumento Intelligente
# (Chat-GPT) nella creazione di un questionario psicologico, prendendo come
# riferimento un test già validato e riconosciuto in letteratura. Sono stati creati due
# questionari e, successivamente, sono state confrontate le statistiche di validità e
# attendibilità (di questi concetti si parlerà nel secondo capitolo) tra le tre versioni,
# quella originale e le due Artificiali.
#
# ## Processo di creazione di un test con Chat-GPT
# La ricerca condotta ha l’obiettivo di verificare l’attendibilità e la validità di due
# questionari creati con l’IA Generativa, in particolare il chatbot sviluppato da
# OpenAI, Chat-GPT (Castigli et al., 2024). Prendendo come riferimento il Body
# Awereness Questionnaire (Shields et al., 1989) si sono formulati diversi prompt e
# tra questi sono stati scelti quello che presentava le maggiori specifiche e quello,
# invece, con quasi nessuna specifica. Successivamente, sono stati creati tre Google
# Form per la somministrazione e diffusione dei questionari. I soggetti coinvolti nella
# ricerca sono studenti di diverse facoltà presso l’Università del Salento. Al termine
# della somministrazione, si sono svolte le indagini statistiche con l’ausilio del
# software RStudio. Di seguito si illustrerà nel dettaglio la metodologia.\
# Consultando
# il
# sito
# Psychological
# tests
# for
# student
# use
# (https://www.yorku.ca/rokada/psyctest/), che permette di scaricare diversi
# questionari liberamente, si è trovata la struttura del BAQ (Body Awereness
# Questionnaire). Il test è costituito da 18 item, le cui modalità di risposta sono
# comprese in una scala da 1 a 7 punti, dove 1=” Per niente vero per me” e 7=” Molto
# vero per me”. Il questionario intende misurare il grado di consapevolezza e
# attenzione delle reazioni corporee non dovute a stati mentali o emotivi, in
# particolare dei cicli e dei ritmi corporei, dei piccoli cambiamenti nella funzionalità
# e l’anticipazione delle reazioni (Shields et al., 1989).
#
#
# 1.   Noto le differenze nel modo in cui il mio corpo reagisce ai diversi cibi.
# 2. Riesco sempre a dire quando urto a prescindere se si crei un livido o meno.
# 3. Riesco sempre a dire quando mi sono esercitato fino al punto di essere indolenzito il giorno dopo.
# 4. Sono sempre consapevole dei cambiamenti nei miei livelli di energia quando mangio alcuni cibi.
# 5. So in anticipo quando sta per venirmi l’influenza.
# 6. So di avere la febbre senza misurare la temperatura.
# 7. Riesco a distinguere tra la stanchezza dovuta alla fame e stanchezza per via
# di una mancanza di sonno.
# 8. Posso accuratamente predire in che momento della giornata la mancanza di sonno mi raggiungerà.
# 9.  Sono consapevole di un ciclo nei miei livelli di attività durante la giornata.
# 10. Non noto cicli e ritmi stagionali nel modo in cui il mio corpo funziona.
# 11. Appena mi sveglio al mattino, so quanta energia avrò durante la giornata.
# 12. Quando vado a letto posso dire quanto bene dormirò quella notte.
# 13. Noto distinte reazioni corporee quando sono affaticato.
# 14. Noto specifiche risposte corporee ai cambiamenti nel tempo atmosferico.
# 15. Posso predire di quanto sonno ho bisogno la notte per svegliarmi
# rinfrescato.
# 16. Quando le mie abitudini di esercizio cambiano, posso predire molto
# accuratamente come influirà sui miei livelli di energia.
# 17. Sembra esserci un tempo migliore per me per andare a dormire la notte.
# 18. Noto specifiche reazioni del mio corpo all’essere troppo affamato.
#
# Il questionario è rivolto a studenti universitari e adulti non studenti, in particolare
# persone con un grado di istruzione superiore ed occupate in lavori d’ufficio.
# L’analisi fattoriale dimostra che il test viene descritto da quattro fattori: notare le
# risposte o i cambiamenti nei processi corporei, predire le reazioni corporee, cicli
# sonno-veglia, ed esordio delle malattie. Sono stati effettuati anche i test per
# verificare la validità convergente e divergente (Shields et al., 1989).\
# Tenendo conto di questi risultati, si è chiesto a Chat-GPT di ricreare un test che
# fosse simile al BAQ originale. I prompt e le chat utilizzate variano, così da
# sperimentare e limitare gli effetti dell’influenza di interazioni precedenti. Il primo
# prompt ha un grado di specifiche molto elevato, in cui vengono anche forniti esempi
# di possibili domande sulla base di quelle presenti in letteratura.
#
# > Devi creare un test psicologico che valuti l’attenzione degli individui verso i normali processi corporei, non dovuti a stati emotivi. Gli item del test sono 18 e
# devono riferirsi a processi che avvengono con sufficiente frequenza e intensità così
# da permettere un’auto-misurazione, e/o devono riferirsi al rilevamento di processi
# che sono empiricamente verificabili. Il test è rivolto a studenti universitari e a
# adulti lavoratori con almeno il grado di istruzione superiore e impiegati in lavori
# d’ufficio. Le risposte degli item devono essere incluse in una scala a 7 punti in cui
# “1=Per niente vero per me” e “7=Molto vero per me”. La struttura del test è
# descritta da 4 fattori: notare risposte o cambiamenti nei processi corporei (che
# include item riferiti alle reazioni ai tipi di cibo, cibo e livelli di energia, ritmi
# stagionali, reazioni alla fatica, reazioni al tempo atmosferico, esercizio fisico e
# livelli di energia); predire le reazioni corporee (che include item riferiti al predire
# al predire lividi, predire indolenzimento muscolare, predire livelli di energia,
# predire qualità del sonno, predire il bisogno di sonno); cicli sonno-veglia (che
# include item riferiti al riconoscere la stanchezza da fame o sonnolenza, predire gli
# effetti di carenza di sonno, ciclo di attività nella giornata, reazioni alla fame, tempi
# di sonno); esordio delle malattie (che include item riferiti al predire l’influenza,
# rilevare la febbre).
#
# Di seguito le domande create a partire da questa formulazione:
#
# 1. Sono solito/a notare le reazioni del mio corpo ai diversi tipi di cibo.
# 2. Posso prevedere se avrò lividi dopo un trauma minore.
# 3. Riesco a prevedere se i miei muscoli saranno indolenziti dopo un’intensa
# attività fisica.
# 4. Riesco a percepire un legame tra il cibo che consumo e i miei livelli di
# energia.
# 5. Posso prevedere se sto per ammalarmi di influenza basandomi sui segnali
# del mio corpo.
# 6. Riesco a rilevare quando ho la febbre senza utilizzare un termometro.
# 7. Sono consapevole quando la mia stanchezza è dovuta alla fame o alla
# mancanza di sonno
# 8. Riesco a prevedere gli effetti della mancanza di sonno sulla mia produttività
# e il mio umore.
# 9. Sono consapevole dei miei cicli di attività durante il giorno e della loro
# relazione con il mio livello di energia.
# 10. [Non] Sono consapevole dei cambiamenti stagionali e del loro impatto sul
# mio corpo.
# 11. Sono in grado di percepire quando il mio corpo necessita di un aumento o una diminuzione dell’energia.
# 12. Sono in grado di predire la qualità del mio sonno basandomi sulle mie
# attività e abitudini quotidiane.
# 13. Sento quando il mio corpo è esausto e ho bisogno di riposo.
# 14. Riesco a rilevare come il tempo atmosferico influenzi il mio stato d’animo
# e il mio livello di energia.
# 15. Posso anticipare il mio bisogno di sonno in base alla mia attività e
# stanchezza.
# 16. Ho familiarità con i segnali che il mio corpo invia quando ho bisogno di
# esercizio fisico.
# 17. Sono consapevole dei miei tempi di sonno ideali e della loro influenza sul
# mio benessere.
# 18. Riesco a percepire quando il mio corpo ha bisogno di cibo per soddisfare la
# fame.
#
# Gli item creati sono stati messi nello stesso ordine di quelli originali ed è stato
# aggiunto l’item reverse alla decima domanda. Questo è stato possibile per via della
# forte somiglianza tra le domande del BAQ originale e quello creato dall’IA.
# Nonostante alcune domande presentino riferimenti alla sfera emotiva (“stati
# d’animo”, “umore”), non presenti nel test originale ed esplicitamente non collegati
# a ciò che si vuole indagare, si è mantenuta questa formulazione nella creazione del
# primo modulo Google da somministrare.\
# Successivamente sono stati creati altri prompt. Il secondo è stato presentato in
# una chat diversa e presenta il minor grado di specifiche.
#
# > Devi creare un test psicologico di 18 item che valuti i normali processi corporei
# non dovuti a stati emotivi. La risposta agli item deve essere compresa in una scala a 7
# punti dove 1=” Per niente vero per me” e 7=” Molto vero per me”.
#
# Di seguito la versione del test creata grazie a questa formulazione:
#
# 1. Spesso mi accorgo dei miei battiti cardiaci.
# 2. Sono consapevole della mia respirazione senza alcun motivo specifico.
# 3. Ho frequenti sensazioni di fame o sazietà.
# 4. Riesco a percepire quando la mia temperatura corporea è diversa dalla
# norma.
# 5. Mi rendo conto delle sensazioni di sete o non sete.
# 6. Sento la necessità di muovere il mio corpo o di cambiare posizione quando
# sono seduto o sdraiato.
# 7. Riesco a distinguere tra sensazioni di affaticamento e di energia nel mio
# corpo.
# 8. Sono consapevole delle mie sensazioni digestive (ad esempio, stomaco
# pieno, digestione).
# 9. Sono in grado di rilevare tensioni muscolari o rigidità nel mio corpo.
# 10. Percepisco i miei livelli di energia fisica durante il giorno.
# 11. Mi rendo conto quando ho bisogno di dormire o di riposare.
# 12. Sono consapevole delle sensazioni di comfort o disagio fisico.
# 13. Riesco a distinguere tra fame fisica e fame emotiva.
# 14. Sento le variazioni nel mio appetito in risposta all’attività fisica o al riposo.
# 15. Sono consapevole dei miei bisogni fisici di evacuazione.
# 16. Percepisco i segnali del mio corpo quando sono disidratato.
# 17. Sono in grado di rilevare cambiamenti nel mio ritmo cardiaco durante lo
# sforzo fisico.
# 18. Mi accorgo quando la mia postura è scorretta o quando mi sento teso
# fisicamente.
#
# Questo output presenta domande leggermente diverse rispetto al BAQ originale;
# di conseguenza, l’ordine degli item non è stato cambiato e non si è aggiunto l’item
# reverse. Anche qui ci sono riferimenti al piano emotivo (“fame emotiva”), ma si è
# comunque usata questa versione per la creazione del secondo modulo Google da
# somministrare. Mantenendo la stessa chat, si è inviato un prompt che avesse un
# grado di specifiche leggermente maggiore.
#
# >Devi creare un test psicologico di 18 item che valuti i normali processi corporei
# non dovuti a stati emotivi, soprattutto sensibilità ai ritmi e cicli corporei, abilità di
# notare piccoli cambiamenti nel normale funzionamento e abilità di prevedere le
# reazioni corporee. La risposta agli item deve essere compresa in una scala a 7 punti
# dove 1=” Per niente vero per me” e 7=” Molto vero per me”.
#
# L’output derivante da questo prompt era semplicemente una riformulazione
# delle domande precedentemente generate, a cui sono stati aggiunti esempi sulla
# base delle specifiche fornite. Si è preferito mantenere la formulazione precedente
# per valutare il grado di variabilità tra i test, ipotizzando un’influenza da parte del
# prompt su questa.\
# Lo stesso input è stato utilizzato in una nuova chat. È curioso notare come le
# domande generate in questo caso facessero molto riferimento alla sfera emotiva
# (“stress”, “fame emotiva”, “benessere mentale”, “umore”, “stato emotivo”, etc.)
# nonostante sia esplicitato il contrario nel prompt. Questo fenomeno è andato man
# mano ad aumentare tanto più si creavano nuove conversazioni e nuovi messaggi.
# Per questo motivo, non verrà di seguito riportato l’output risultante dalla ricerca.
#
# ## Rilevazione dei dati e caratteristiche descrittive del campione
#
# Selezionate le versioni del questionario da somministrare, si è proceduto a creare
# tre Google Form, ognuno con una formulazione diversa. La struttura dei moduli era
# organizzata in modo che appena aperti si visualizzasse il consenso informato, che
# spiegava gli obiettivi della ricerca e garantiva che i dati sensibili non sarebbero stati
# raccolti o divulgati, e le domande riguardanti i dati anagrafici dei soggetti. In
# particolare, si è chiedeva: sesso alla nascita, età in anni compiuti, provincia
# d’appartenenza, titolo di studio e dipartimento del corso di laurea attualmente
# frequentato (poiché la somministrazione dei questionari è avvenuta esclusivamente
# tra gli studenti dell’Università del Salento). Una sezione separata era dedicata alle
# domande del questionario di riferimento.\
# I soggetti che hanno preso parte alla ricerca si sono distribuiti in tre sottogruppi
# indipendenti fra loro, per un campione complessivo di 178 individui. In particolare,
# 56 soggetti hanno risposto alle domande del BAQ originale; 57 soggetti hanno
# risposto alle domande generate da Chat-GPT con il prompt avente le maggiori
# specifiche (d’ora in poi Versione 1); 65 soggetti hanno risposto alle domande
# generate da Chat-GPT con il prompt più generico (d’ora in poi Versione 2). L’età
# media del sottogruppo a cui è stato somministrato il BAQ è di 22,89 anni (sd =
# 6,19) e hanno risposto soprattutto individui di sesso femminile (F: 82,1%; M:
# 17,9%); i soggetti provengono principalmente dalla provincia di Lecce (Lecce:
# 49,1%; Brindisi: 21,8%; Taranto: 20%; Bari: 9,1%), hanno studiato per lo più al
# Liceo delle Scienze Umane e al Liceo Linguistico, e fanno principalmente parte del
# Dipartimento di Scienze Umane e Sociali dell’Università del Salento.\
# L’età media del sottogruppo a cui è stata somministrata la Versione 1 è di 23,24
# anni (sd = 4,60) e hanno risposto soprattutto individui di sesso femminile (F: 66,7%;
# M: 33,3%); i soggetti provengono principalmente dalla provincia di Lecce (Lecce: 54,4%; Taranto: 24,6%; Brindisi: 12,3%; Foggia e Bari: 3,5%; BAT: 1,8%),
# hanno studiato per lo più al Liceo Scientifico, e fanno principalmente parte del
# Dipartimento di Scienze Umane e Sociali dell’Università del Salento.\
# L’età media del sottogruppo a cui è stata somministrata la Versione 2 è di
# 21,66 anni (sd = 3,49) e hanno risposto soprattutto individui di sesso femminile
# (F: 93,8%; M: 6,2%); i soggetti provengono principalmente dalla provincia di
# Lecce (Lecce: 70,8%; Brindisi: 18,5%; Taranto: 7,7%; Foggia e BAT: 1,5%),
# hanno studiato per lo più al Liceo delle Scienze Umane e al Liceo Scientifico, e
# fanno principalmente parte del Dipartimento di Scienze Umane e Sociali
# dell’Università del Salento.\
# Gli individui che hanno preso parte alla ricerca sono colleghi di corso e loro
# conoscenze, per questo motivo non si tratta di un campione probabilistico.\
# La somministrazione dei test è andata avanti per circa due settimane, tempo
# necessario ad arrivare alla soglia minima di 150 soggetti. Dopo la chiusura dei
# moduli, si sono svolte le statistiche con l’ausilio del software RStudio.
#
# ### Analisi descrittiva dei risultati
#
# Per prima cosa si sono importati i dataset in formato Excel. Successivamente,
# con il comando `colnames` si è cambiato il nome degli item per ogni tabella, in
# modo da essere facilitati nella scrittura dei codici e nell’analisi dei risultati. Nel
# BAQ originale gli item sono stati rinominati, in ordine: N15, P12, P13, N16, M3,
# M4, C10, C11, C12, N17, P14, P15, N18, N19, P16, N20, C13, C14; nella
# Versione 1 gli item sono stati rinominati, in ordine: N1, P1, P2, N2, M1, M2,
# C1, C2, C3, N3, P3, P4, N4, N5, P5, N6, C4, C5; nella Versione 2 gli item sono
# stati rinominati, in ordine: N7, N8, P6, N9, N10, P7, P8, N11, P9, C6, C7, N12,
# C8, C9, P10, N13, N14, P11. Con il comando `as.matrix` si sono create delle
# matrici a partire dai dataset, nominate rispettivamente CO, C1 e C2. A questo
# punto si sono calcolate le statistiche descrittive (media e deviazione standard)
# per ogni item e per ogni questionario. Pur essendo le risposte associate a caratteri qualitativi ordinali, ai fini della presente analisi associamo a tali dati una descrizione quantitativa per poter condurre un confronto sulla base di indici e statistiche comunemente usate e interpretabili in modo pratico nell'ambito della ricerca psicologica.

# %%
library(readr)
BAQ <- read_csv("Questionario sulla consapevolezza corporea (Body Awereness Questionnaire) (Risposte) - Risposte del modulo 1.csv")
Versione1 <- read.csv("Chat-GPT, ver.1 (Risposte) - Risposte del modulo 1.csv")
Versione2 <- read.csv("Chat-GPT, ver. 2 (Risposte) - Risposte del modulo 1.csv")

colnames(BAQ) <- c("N15", "P12", "P13", "N16", "M3", "M4", "C10", "C11", "C12", "N17", "P14", "P15", "N18", "N19", "P16", "N20", "C13", "C14")
CO <- as.matrix(BAQ)
colnames(Versione1) <- c("N1", "P1", "P2", "N2", "M1", "M2", "C1", "C2", "C3", "N3", "P3", "P4", "N4", "N5", "P5", "N6", "C4", "C5")
C1 <- as.matrix(Versione1)
colnames(Versione2) <- c("N7", "N8", "P6", "N9", "N10", "P7", "P8", "N11", "P9", "C6", "C7", "N12", "C8", "C9", "P10", "N13", "N14", "P11")
C2 <- as.matrix(Versione2)
# Out:
# Rows: 56 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (18): Noto le differenze nel modo in cui il mio corpo reagisce a diversi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
print("La media del BAQ è:")
mean(CO)
print("La deviazione standard del BAQ è:")
sd(CO)
# Out:
# [1] "La media del BAQ è:"
# [1] 4.579365
# [1] "La deviazione standard del BAQ è:"
# [1] 1.919857

# %%
install.packages("psych")
psych::describe(CO)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#     vars n  mean     sd       median trimmed  mad    min max range skew
# N15  1   56 5.589286 1.604276 6.0    5.804348 1.4826 1   7   6     -0.885330287
# P12  2   56 4.839286 1.866224 5.0    4.978261 2.9652 1   7   6     -0.363785887
# P13  3   56 5.107143 1.754771 6.0    5.282609 1.4826 1   7   6     -0.675857095
# N16  4   56 4.125000 1.769052 4.0    4.152174 1.4826 1   7   6     -0.205319940
# M3   5   56 4.500000 1.737292 4.0    4.608696 1.4826 1   7   6     -0.326937779
# M4   6   56 4.660714 1.993414 5.0    4.804348 2.9652 1   7   6     -0.429128015
# C10  7   56 4.642857 2.083952 5.0    4.782609 2.9652 1   7   6     -0.429209217
# C11  8   56 4.839286 1.604276 5.0    4.934783 1.4826 1   7   6     -0.339583614
# C12  9   56 4.678571 1.696061 5.0    4.739130 1.4826 1   7   6     -0.269294058
# N17 10   56 3.928571 1.943354 3.5    3.913043 2.2239 1   7   6      0.215402096
# ...

# %%
print("La media della Versione 1 è:")
mean(C1)
print("La deviazione standard della Versione 1 è:")
sd(C1)
# Out:
# [1] "La media della Versione 1 è:"
# [1] 5.034113
# [1] "La deviazione standard della Versione 1 è:"
# [1] 1.72211

# %%
psych::describe(C1)
# Out:
#    vars n  mean     sd        median trimmed  mad    min max range skew
# N1  1   57 4.578947 1.9815882 5      4.702128 2.9652 1   7   6     -0.31110838
# P1  2   57 4.122807 2.0621606 5      4.148936 2.9652 1   7   6     -0.20974465
# P2  3   57 5.456140 1.2402502 6      5.531915 1.4826 3   7   4     -0.34288008
# N2  4   57 4.350877 1.8467271 4      4.382979 2.9652 1   7   6     -0.09330736
# M1  5   57 5.368421 1.4836198 6      5.531915 1.4826 1   7   6     -0.82780468
# M2  6   57 5.087719 1.6932714 5      5.255319 1.4826 1   7   6     -0.61175924
# C1  7   57 5.385965 1.3855683 6      5.510638 1.4826 2   7   5     -0.69753745
# C2  8   57 5.894737 1.3186060 6      6.106383 1.4826 2   7   5     -1.27931900
# C3  9   57 4.982456 1.5058366 5      5.085106 1.4826 1   7   6     -0.43321520
# N3 10   57 4.368421 2.0670163 5      4.446809 2.9652 1   7   6     -0.13170478
# P3 11   57 4.543860 1.6373997 5      4.595745 1.4826 1   7   6     -0.38818372
# ...

# %%
print("La media della Versione 2 è:")
mean(C2)
print("La deviazione standard della Versione 2 è:")
sd(C2)
# Out:
# [1] "La media della Versione 2 è:"
# [1] 5.309402
# [1] "La deviazione standard della Versione 2 è:"
# [1] 1.659665

# %%
psych::describe(C2)
# Out:
#     vars n  mean     sd       median trimmed  mad    min max range skew
# N7   1   65 4.661538 1.734547 5      4.773585 1.4826 1   7   6     -0.33006918
# N8   2   65 4.200000 1.813146 4      4.226415 1.4826 1   7   6      0.01610544
# P6   3   65 5.000000 1.629801 5      5.113208 1.4826 1   7   6     -0.51173570
# N9   4   65 5.276923 1.525898 5      5.452830 1.4826 1   7   6     -0.82784169
# N10  5   65 5.861538 1.367901 6      6.094340 1.4826 2   7   5     -1.16056020
# P7   6   65 6.046154 1.164994 6      6.207547 1.4826 2   7   5     -1.08036091
# P8   7   65 5.892308 1.459057 6      6.150943 1.4826 1   7   6     -1.53989854
# N11  8   65 5.323077 1.542195 5      5.471698 1.4826 2   7   5     -0.53991773
# P9   9   65 5.369231 1.495506 6      5.547170 1.4826 1   7   6     -0.96511706
# C6  10   65 5.307692 1.478207 6      5.490566 1.4826 1   7   6     -1.07159102
# C7  11   65 5.953846 1.351281 6      6.188679 1.4826 1   7   6     -1.75091908
# ...

# %% [markdown]
# Dal confronto delle statistiche descrittive abbiamo un riscontro preliminare della
# mancanza di differenze tra i tre questionari.
#
# ### Analisi dell'attendibilità
#
# Il passo successivo è stato calcolare le α di Cronbach per ogni test e confrontarle. Per farlo, c’è stato bisogno di scaricare il pacchetto `cocron` per R dal sito cocron - comparing Cronbach alphas. http://comparingcronbachalphas.org/. Questo
# pacchetto permette di comparare n coefficienti α dipendenti o indipendenti
# (Cronbach, 1951), con l’implementazione dei metodi di Feldt, Woodruff e Salih
# (1987). Di seguito i comandi per calcolare le alpha:

# %%
install.packages("cocron")
print("L'α di Cronbach del BAQ è:")
cocron::cronbach.alpha(CO)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# [1] "L'α di Cronbach del BAQ è:"
#     alpha
# 0.8391284

# %%
print("L'α di Cronbach della Versione 1 è:")
cocron::cronbach.alpha(C1)
# Out:
# [1] "L'α di Cronbach della Versione 1 è:"
#     alpha
# 0.7746769

# %%
print("L'α di Cronbach della Verisone 2 è:")
cocron::cronbach.alpha(C2)
# Out:
# [1] "L'α di Cronbach della Verisone 2 è:"
#     alpha
# 0.8169547

# %% [markdown]
# In seguito, si sono confrontati i punteggi di tutti e tre i test. Si è prima creato un
# vettore che contenesse le α, poi un vettore che contenesse le numerosità dei
# sottogruppi, e infine si è eseguito il confronto. Di seguito i comandi per confrontare
# tutti i test tra loro:

# %%
alpha<-c(0.775, 0.817, 0.840)
n<-c(57, 65, 56)
cocron::cocron.n.coefficients(alpha, n, items = 18,
dep = FALSE, los = 0.10, conf.level = 0.90)
# Out:
#   Compare n alpha coefficients
#
# Comparison between: a1 = 0.775, a2 = 0.817, a3 = 0.84
# The coefficients are based on independent groups
# 90% confidence intervals: CI1 = 0.6976 0.8413, CI2 = 0.7584 0.8677, CI3 = 0.7844 0.8875
# Group sizes: n1 = 57, n2 = 65, n3 = 56
# Item count: i1 = 18, i2 = 18, i3 = 18
# Null hypothesis: a1, a2, and a3 are equal
# Alternative hypothesis: a1, a2, and a3 are not equal
# Level of significance: 0.1
#
# chisq = 1.5064, df = 2, p-value = 0.4708
# Null hypothesis retained

# %% [markdown]
# Questo confronto ha riportato un valore del p-value uguale a 0.47. Nonostante
# non si sia rilevata una differenza significativa tra i test, si è proceduto a effettuare
# l’analisi tra coppie di test, in modo da avere un’informazione più dettagliata.\
# Anche in questo caso, si sono prima creati dei vettori contenenti le alpha dei test
# confrontati e dei vettori con la numerosità dei sottogruppi. Di seguito i comandi:

# %%
alphaC1C2<-c(0.775, 0.817)
alphaC2CO<-c(0.817,0.840)
alphaC1CO<-c(0.775,0.840)
n12<-c(57,65)
n2O<-c(65, 56)
n1O<-c(57,56)

print("Confronto tra Versione 1 e Versione 2:")
cocron::cocron.two.coefficients(alphaC1C2, n12, dep
= FALSE, los = 0.05, alternative = "two.sided")
# Out:
# [1] "Confronto tra Versione 1 e Versione 2:"
#   Compare two alpha coefficients
#
# Comparison between: a1 = 0.817, a2 = 0.775
# The coefficients are based on independent groups
# Group sizes: n1 = 65, n2 = 57
# Null hypothesis: a1 is equal to a2
# Alternative hypothesis: a1 is not equal to a2 (two-sided)
# Level of significance: 0.05
#
# F = 1.2295, df1 = 64, df2 = 56, p-value = 0.4314
# Null hypothesis retained

# %%
print("Confronto tra Versione 2 e BAQ:")
cocron::cocron.two.coefficients(alphaC2CO, n2O, dep
= FALSE, los = 0.05, alternative = "two.sided")
# Out:
# [1] "Confronto tra Versione 2 e BAQ:"
#   Compare two alpha coefficients
#
# Comparison between: a1 = 0.84, a2 = 0.817
# The coefficients are based on independent groups
# Group sizes: n1 = 56, n2 = 65
# Null hypothesis: a1 is equal to a2
# Alternative hypothesis: a1 is not equal to a2 (two-sided)
# Level of significance: 0.05
#
# F = 1.1438, df1 = 55, df2 = 64, p-value = 0.6019
# Null hypothesis retained

# %%
print("Confronto tra Versione 1 e BAQ:")
cocron::cocron.two.coefficients(alphaC1CO, n1O, dep
= FALSE, los = 0.05, alternative = "two.sided")
# Out:
# [1] "Confronto tra Versione 1 e BAQ:"
#   Compare two alpha coefficients
#
# Comparison between: a1 = 0.84, a2 = 0.775
# The coefficients are based on independent groups
# Group sizes: n1 = 56, n2 = 57
# Null hypothesis: a1 is equal to a2
# Alternative hypothesis: a1 is not equal to a2 (two-sided)
# Level of significance: 0.05
#
# F = 1.4062, df1 = 55, df2 = 56, p-value = 0.2067
# Null hypothesis retained

# %% [markdown]
# I risultati ottenuti confermano che non ci sono differenze significative tra i test.
#
# ### Analisi della validità
# Successivamente si è svolta l’Analisi in Componenti Principali per condurre una
# valutazione esplorativa della validità. È stato necessario installare il pacchetto
# `FactoMiner` su RStudio. Con il seguente script, è stato possibile avere un’analisi
# completa con pochi comandi:

# %%
install.packages("FactoMineR")
library(FactoMineR)
res.pca1=PCA(C1)
summary(res.pca1)
lapply(dimdesc(res.pca1),lapply,round,6)
head(res.pca1$eig)
round(res.pca1$var$contrib,3)
round(res.pca1$var$cos2,3)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘pbkrtest’, ‘car’
# Call:
# PCA(X = C1)
#
#
# Eigenvalues
#                        Dim.1   Dim.2   Dim.3   Dim.4   Dim.5   Dim.6   Dim.7
# Variance               4.721   1.771   1.604   1.477   1.182   0.993   0.951
# % of var.             26.228   9.840   8.912   8.206   6.565   5.515   5.286
# Cumulative % of var.  26.228  36.067  44.979  53.185  59.750  65.265  70.550
#                        Dim.8   Dim.9  Dim.10  Dim.11  Dim.12  Dim.13  Dim.14
# Variance               0.889   0.825   0.651   0.574   0.515   0.485   0.406
# % of var.              4.939   4.585   3.616   3.189   2.860   2.697   2.253
# Cumulative % of var.  75.489  80.074  83.690  86.879  89.739  92.436  94.689
#                       Dim.15  Dim.16  Dim.17  Dim.18
# Variance               0.336   0.300   0.190   0.131
# % of var.              1.866   1.665   1.054   0.726
# ...

# %%
plot(res.pca1,choix="var")
# Out:
# plot without title

# %%
barplot(res.pca1$eig[,1], main="Scree-plot degli autovalori (Versione 1)", col = "springgreen3")
# Out:
# Plot with title “Scree-plot degli autovalori (Versione 1)”

# %%
res.pca2=PCA(C2)
summary(res.pca2)
lapply(dimdesc(res.pca2),lapply,round,6)
head(res.pca2$eig)
round(res.pca2$var$contrib,3)
round(res.pca2$var$cos2,3)
# Out:
# Call:
# PCA(X = C2)
#
#
# Eigenvalues
#                        Dim.1   Dim.2   Dim.3   Dim.4   Dim.5   Dim.6   Dim.7
# Variance               5.000   2.084   1.661   1.236   1.137   0.967   0.863
# % of var.             27.777  11.580   9.229   6.869   6.319   5.374   4.795
# Cumulative % of var.  27.777  39.357  48.586  55.455  61.774  67.148  71.943
#                        Dim.8   Dim.9  Dim.10  Dim.11  Dim.12  Dim.13  Dim.14
# Variance               0.765   0.664   0.610   0.566   0.496   0.477   0.371
# % of var.              4.250   3.691   3.391   3.142   2.756   2.650   2.061
# Cumulative % of var.  76.192  79.883  83.275  86.417  89.172  91.822  93.883
#                       Dim.15  Dim.16  Dim.17  Dim.18
# Variance               0.328   0.316   0.241   0.217
# % of var.              1.820   1.753   1.338   1.206
# Cumulative % of var.  95.703  97.456  98.794 100.000
#
# Individuals (the 10 first)
#         Dist    Dim.1    ctr   cos2    Dim.2    ctr   cos2    Dim.3    ctr
# ...

# %%
plot(res.pca2,choix="var")
# Out:
# plot without title

# %%
barplot(res.pca2$eig[,1],main="Scree-plot degli autovalori (Versione 2)", col = "purple")
# Out:
# Plot with title “Scree-plot degli autovalori (Versione 2)”

# %%
res.pcaO=PCA(CO)
summary(res.pcaO)
lapply(dimdesc(res.pcaO),lapply,round,6)
head(res.pcaO$eig)
round(res.pcaO$var$contrib,3)
round(res.pcaO$var$cos2,3)
# Out:
# Call:
# PCA(X = CO)
#
#
# Eigenvalues
#                        Dim.1   Dim.2   Dim.3   Dim.4   Dim.5   Dim.6   Dim.7
# Variance               5.151   1.930   1.574   1.352   1.167   1.060   0.989
# % of var.             28.617  10.722   8.742   7.513   6.483   5.889   5.493
# Cumulative % of var.  28.617  39.339  48.081  55.594  62.076  67.965  73.458
#                        Dim.8   Dim.9  Dim.10  Dim.11  Dim.12  Dim.13  Dim.14
# Variance               0.774   0.712   0.600   0.567   0.455   0.399   0.362
# % of var.              4.299   3.953   3.334   3.153   2.526   2.219   2.010
# Cumulative % of var.  77.757  81.710  85.045  88.197  90.723  92.943  94.952
#                       Dim.15  Dim.16  Dim.17  Dim.18
# Variance               0.304   0.246   0.200   0.160
# % of var.              1.686   1.364   1.110   0.887
# Cumulative % of var.  96.639  98.003  99.113 100.000
#
# Individuals (the 10 first)
#         Dist    Dim.1    ctr   cos2    Dim.2    ctr   cos2    Dim.3    ctr
# ...

# %%
plot(res.pcaO,choix="var")
# Out:
# plot without title

# %%
barplot(res.pcaO$eig[,1], main="Scree-plot degli autovalori (BAQ)", col = "pink")
# Out:
# Plot with title “Scree-plot degli autovalori (BAQ)”

# %% [markdown]
# Il comando `library` richiama l’utilizzo del pacchetto `FactoMiner`. Il
# comando `PCA` svolge l’Analisi in Componenti Principali riducendo la
# dimensionalità dei dati con una minima perdita di informazione, permettendo
# anche di visualizzarli graficamente. Con `summary` si produce un report
# sull’importanza delle componenti in termini di deviazione standard (sd) e
# proporzione della varianza spiegata e della varianza spiegata cumulata sia per gli
# individui che per le variabili. `lapply` restituisce la misura delle correlazioni e del
# p-value, mentre `dimdesc` fornisce una descrizione che precisa quali variabili siano
# maggiormente caratteristiche secondo ciascuna dimensione. Si specifica `lapply`
# in modo da applicare tali funzioni a un elenco (lista) e non un vettore, e `round`
# specifica a quanti numeri dopo la virgola arrotondare. Con il comando `plot` si
# disegna il cerchio delle correlazioni; con `choix` si scelgono i dati da rappresentare
# (in questo caso le variabili). Il comando `round` formatta i valori, in questo caso i
# contributi delle singole modalità alla varianza e i 𝑐𝑜𝑠2, arrotondati alla terza cifra
# dopo la virgola. Con il comando `barplot` si disegna il diagramma a barre degli
# autovalori (scree-plot), dandoci informazioni della varianza spiegata da ogni
# componente.\
# I risultati restituiti suggeriscono che: nel BAQ originale nove dimensioni
# spiegano l’81,71% della varianza totale; nella Versione 1 nove dimensioni spiegano
# l’80,07% della varianza totale; nella Versione 2 dieci dimensioni spiegano
# l’83,27% della varianza totale.
#
# ### Discussione
# Dai risultati sembrerebbe non esserci una differenza statisticamente significativa
# tra i tre questionari.\
# Nella selezione dei test creati con l’IA, il riscontro di un progressivo aumento
# delle domande legate a stati emotivi o mentali (esplicitamente non richiesti nella
# formulazione del prompt) potrebbe far pensare ad un’influenza delle passate
# interazioni con il modello Artificiale non solo nello stesso spazio di comunicazione,
# ma anche in chat diverse.\
# Per quanto riguarda l’attendibilità, misurata con le α di Cronbach, tutti e tre i test
# risultano attendibili; in particolare, l’alpha del BAQ originale (α = 0.84) non è
# diversa da quella riscontrata in letteratura (α = 0.83). È interessante notare come
# l’alpha della Versione 1 (α = 0.77) sia molto differente rispetto a quella del BAQ
# originale, nonostante fosse la riformulazione che presentava il prompt con maggiori
# specifiche e con domande più simili. Ciò potrebbe far pensare ad un effetto di
# confusione generato dal grado di dettaglio del prompt; formulazioni più aperte,
# meno dettagliate, potrebbero permettere al modello di cercare tra più dati per
# giungere ad una risposta ottimale. Questa ipotesi potrebbe essere avvalorata sia dal
# valore dell’alpha della Versione 2 (α = 0.82) che dal p-value ottenuto dal confronto tra le α del BAQ originale e della Versione 1, il quale, seppur non statisticamente
# significativo, risulta essere il più basso tra i vari confronti (p-value = 0.21),
# permettendo di ipotizzare che queste due versioni siano quelle più differenti tra loro.\
# Per quanto riguarda la validità, con la PCA si ottengono per i tre questionari
# risultati concordi con quella presenti in letteratura. In particolare, ci si aspetta dai
# quattro ai sei fattori che spieghino la varianza dei test. Dai grafici degli scree-plot,
# che ci danno informazioni sulla varianza spiegata, notiamo che il numero di
# componenti con un autovalore maggiore di 1 rientra in questo range per ogni
# formulazione del questionario. È importante sottolineare il fatto che si tratta di due
# analisi diverse: la PCA è un’analisi esplorativa che non si fonda su specifiche
# assunzioni legate a un modello strutturale né a distribuzioni statistiche soggiacenti,
# mentre quella effettuata in letteratura è un’analisi fattoriale. Anche per quanto
# riguarda il cerchio delle correlazioni, si nota una distribuzione simile delle variabili,
# con leggere differenze nella qualità della rappresentazione (lunghezza delle frecce).
# Confrontando i 𝑐𝑜𝑠2, notiamo che: gli item che meglio rappresentano la prima
# dimensione nel BAQ originale sono M3 e M4, permettendoci di ipotizzare che
# questa dimensione faccia riferimento all’esordio delle malattie; la seconda
# dimensione è meglio rappresentata dagli item P12 e P13, facendoci pensare che
# faccia riferimento al predire le reazioni corporee; la terza è meglio rappresentata
# dagli item N15 e N16, riferendosi probabilmente alle reazioni corporee al cibo; la
# quarta dimensione è meglio rappresentata dagli item N17 e C14, facendo forse
# riferimento alla consapevolezza dei cicli di funzionamento; e la quinta dimensione
# è meglio rappresentata dall’item P16, riferendosi ad aspetti legati al sonno. Nella
# Versione 1, la prima dimensione è meglio rappresentata dagli item C2 e C3, facendo
# probabilmente riferimento ad aspetti legati alla stanchezza; la seconda dimensione
# è meglio rappresentata dagli item P1 e P2, riferendosi forse al predire le reazioni
# corporee; la terza dimensione è meglio rappresentata dagli item P4 e C4, facendo
# probabilmente riferimento ad aspetti legati al sonno; la quarta dimensione è meglio
# rappresentata dagli item N5 e C5, riferendosi forse ai livelli di energia; la quinta
# dimensione è meglio rappresentata dall’item N3, facendo riferimento ai
# cambiamenti stagionali. Nella Versione 2, la prima dimensione è meglio
# rappresentata dagli item P6 e C7, facendo probabilmente riferimento alla consapevolezza dei cicli di funzionamento; la seconda dimensione è meglio
# rappresentata dagli item N7 e N8, riferendosi forse al rilevamento delle funzioni
# corporee; la terza dimensione è meglio rappresentata dagli item P11 e N9,
# riferendosi probabilmente alla percezione di malessere; la quarta dimensione è
# meglio rappresentata dall’item C6, facendo riferimento ai livelli di energia; infine,
# la quinta dimensione è meglio rappresentata dagli item N11 e P7, riferendosi
# probabilmente al riconoscimento delle sensazioni.\
# Le dimensioni trovate e la loro distribuzione sono più o meno simili tra i diversi
# questionari. In conclusione, questo studio sembra non aver riscontrato differenze
# significative né per l’attendibilità dei test, né per la loro validità.
# ### Limiti e prospettive future
# Questa ricerca presenta diversi limiti. La traduzione del BAQ originale
# dall’inglese all’italiano è stata effettuata dalla sottoscritta. Oltre a questo, lo studio
# è stato condotto utilizzando un campione non probabilistico, costituito da una forte
# presenza di soggetti femminili. Un miglior campionamento, una maggiore presenza
# maschile per valutare possibili influenze del sesso biologico nella selezione delle
# risposte, e una traduzione più accurata potrebbero essere impiegati in studi futuri.
# Nelle prossime ricerche si potrebbe anche approfondire l’algoritmo, il modello di
# interpretazione dei prompt dell’IA e il modo in cui vengono selezionati i dati
# d’addestramento per spiegare il motivo per cui sono state generate domande che
# non corrispondevano in maniera efficace a ciò che è stato richiesto. Si potrebbero
# formulare prompt diversi, utilizzare altri modelli IA e/o altre tecniche di analisi
# statistica e psicometrica per validare i risultati, come ad esempio effettuare
# un’analisi fattoriale. Ancora, si potrebbe utilizzare uno strumento Intelligente per
# creare un test ex novo per poi valutarne l’attendibilità e la validità convergente e
# discriminante, così da misurare l’effettiva capacità generativa dell’IA piuttosto che
# la sua capacità di emulazione di fonti già esistenti.
#
# ##Conclusioni
# L'obiettivo della ricerca era quello di verificare l’attendibilità e la validità di due strumenti psicologici creati da Chat
# GPT, mettendoli a confronto con il Body Awereness Questionnaire (BAQ), un test
# già validato e presente in letteratura. La ricerca presenta diversi limiti, tra cui il fatto
# di lavorare con un campione non probabilistico, la scarsa presenza di soggetti
# maschili all’interno del campione, l’incapacità di sapere come il modello Artificiale
# abbia selezionato le domande da presentare. Utilizzando le misure dell’α di
# Cronbach, e confrontando fra loro i test, i risultati suggeriscono che non è presente
# una differenza statisticamente significativa tra le tre versioni per quanto riguarda
# l’attendibilità. Con l’Analisi in Componenti Principali non si sono riscontrate
# differenze significative neanche per quanto riguarda la validità. Ricerche future
# potrebbero concentrarsi maggiormente sulla formulazione dei prompt, selezionare
# in maniera più accurata i campioni, utilizzare un altro modello Artificiale o altri test
# statistici, o creare un test originale e validarlo.
#
# ## Riferimenti bibliografici e Sitografia
#
# 1. Castigli, M., Sandonnini, P., Castigli, M., & Sandonnini, P. (2024, June 24).
# ChatGPT guida completa: cos’è, come si usa e cosa può fare per aziende e
# professionisti.
# Agenda
# Digitale.
# https://www.agendadigitale.eu/cultura
# digitale/introduzione-a-chatgpt-cose-come-si-usa-e-cosa-puo-fare/
# 2. cocron -
# comparing
# http://comparingcronbachalphas.org/
# 3. Cronbach, L.J. Coefficient alpha and the internal structure of tests.
# Psychometrika 16, 297–334 (1951). https://doi.org/10.1007/BF02310555
# 4. Feldt, L. S., Woodruff, D. J., & Salih, F. A. (1987). Statistical inferences for
# coefficient
# alpha.
# Applied
# Psychological
# doi:10.1177/014662168701100107
# 5. Psychological
# tests
# https://www.yorku.ca/rokada/psyctest/
# 6. Shields, S. A., Mallory, M. E., & Simon, A. (1989). The Body Awareness
# Questionnaire: Reliability and Validity. Journal of Personality Assessment, 53(4),
# 802–815. https://doi.org/10.1207/s15327752jpa5304_16
